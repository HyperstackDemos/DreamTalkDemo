# %% [markdown]
# # Get voices in multiples languages
#
# Let's fetch some audio recordings in different languages from the [Common Voice dataset](https://huggingface.co/datasets/mozilla-foundation/common_voice_17_0) by the Mozilla Foundation.
